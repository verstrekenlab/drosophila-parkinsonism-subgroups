# %% [markdown]
# # Estimate the posterior probability of an interaction based on observed ERGs
#
# Quantify whether there is an interaction or not between two genes in Drosophila melanogaster PD models

# %%
import os.path
import pandas as pd
import yaml
import seaborn as sns
import arviz as az
import numpy as np
from utils import (
   load_trace,
   min_distance_to_interval
)
import matplotlib.pyplot as plt
import plotly.express as px

# %%
RANDOM_SEED = 58
rng = np.random.default_rng(RANDOM_SEED)

# %%
all_data=pd.read_csv("processed/genetic_interactions_database.csv")
with open("processed/gene_pairs.yaml") as handle:
    gene_pairs=yaml.load(handle, yaml.SafeLoader)

# %%
all_data
# Out:
#       Unnamed: 0 Date_recording                  Genotype  Double  metric  \
# 0              0     2022-01-19            Auxillin[KO]_+   False -2.1637
# 1              1     2022-03-02            Auxillin[KO]_+   False -5.7695
# 2              2     2022-03-02            Auxillin[KO]_+   False -4.5149
# 3              3     2022-03-17            Auxillin[KO]_+   False -5.5708
# 4              4     2022-03-17            Auxillin[KO]_+   False -4.3566
# ...          ...            ...                       ...     ...     ...
# 4321        4321     2025-08-21  Tango14[KO]_+;Park[KO]_+    True -4.7887
# 4322        4322     2025-08-21  Tango14[KO]_+;Park[KO]_+    True -4.4491
# 4323        4323     2025-08-21  Tango14[KO]_+;Park[KO]_+    True -5.2980
# 4324        4324     2025-08-21  Tango14[KO]_+;Park[KO]_+    True -4.3428
# 4325        4325     2025-08-21  Tango14[KO]_+;Park[KO]_+    True -3.5164
#
#       metric_control  metric_norm     WT  metric_inv
# 0          -4.439283     0.487398  False      2.1637
# 1          -5.317360     1.085031  False      5.7695
# 2          -5.317360     0.849087  False      4.5149
# 3          -5.175567     1.076365  False      5.5708
# 4          -5.175567     0.841763  False      4.3566
# ...              ...          ...    ...         ...
# 4321       -4.037671     1.186005  False      4.7887
# 4322       -4.037671     1.101897  False      4.4491
# 4323       -4.037671     1.312142  False      5.2980
# 4324       -4.037671     1.075570  False      4.3428
# 4325       -4.037671     0.870898  False      3.5164
#
# [4326 rows x 9 columns]

# %%
mean_depol=all_data.groupby("Genotype").agg({"metric_norm": np.mean}).reset_index()
double_index=all_data[["Genotype", "Double"]].drop_duplicates()
assert (double_index.value_counts("Genotype")==1).all()
mean_depol=mean_depol.merge(double_index, on="Genotype")
# Out:
# /tmp/ipykernel_1346999/3332494727.py:1: FutureWarning: The provided callable <function mean at 0x770058f37560> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   mean_depol=all_data.groupby("Genotype").agg({"metric_norm": np.mean}).reset_index()

# %%
prefix="2025-09-17"
# prefix="2024-06-27"
# prefix="2024-05-13"
out_folder=f"{prefix}_models/"

# %%
records=[]
delta_z={}
metric="metric_norm"
for pair_id in gene_pairs.keys():
    genes=gene_pairs[pair_id]
    fname = f"{out_folder}/model_{str(pair_id).zfill(3)}.nc"
    if not os.path.exists(fname):
        continue
    trace = load_trace(f"{out_folder}/model_{str(pair_id).zfill(3)}.pkl")
    
    with open(f"{out_folder}/model_{str(pair_id).zfill(3)}.txt", "r") as handle:
        genes=handle.read().split("\n")
    
    data=all_data.loc[all_data["Genotype"].isin(genes )]
    data_hist=all_data.loc[all_data["Genotype"].isin(genes  + ["W1118"])]

    hdi=az.hdi(trace,var_names=["interaction"], hdi_prob = 0.95).to_array().values.flatten().tolist()

    # import ipdb; ipdb.set_trace()

    expected_dm=mean_depol.loc[mean_depol["Genotype"]==genes[0], "metric_norm"].item()*mean_depol.loc[mean_depol["Genotype"]==genes[1], "metric_norm"].item()

    dz=all_data.loc[all_data["Genotype"]==genes[2], "metric_norm"].values - expected_dm
    delta_z[pair_id]=dz
    
    
    records.append((
        pair_id,
        hdi[0],
        hdi[1],
        expected_dm,
        np.mean(dz),
    ))

# %%
data=pd.DataFrame(records, columns=["pair_id", "hdi0", "hdi1", "expected", "mean(observed-expected)"])

# %%
pair_ids=data["pair_id"].values

# %%
for id in [pair for pair in gene_pairs if not pair in pair_ids]:
    print(f"Data not available: {gene_pairs[id]}")

# %%
# format gene names
def remove_gene_suffix(gene):
    return gene.replace("_+", "").replace("_y", "")
    
    
data["single_mutant_0"]=[remove_gene_suffix(gene_pairs[pair_id][0]) for pair_id in data["pair_id"]]
data["single_mutant_1"]=[remove_gene_suffix(gene_pairs[pair_id][1]) for pair_id in data["pair_id"]]

# %%
good_names=pd.read_csv("raw/250911_list_correct_names.txt", sep =" ")
good_names=good_names.loc[~good_names["correct_name"].isna()]
good_names={remove_gene_suffix(row["original_name"]): remove_gene_suffix(row["correct_name"]) for _, row in good_names.iterrows()}

# %%
data["single_mutant_0"].unique()
# Out:
# array(['Auxillin[KO]', 'CG32000[KO]', 'CG5010[KO]', 'CG5608[KO]',
#        'Coq2[KO]', 'Dj1a[KO];DJ1b[KO]', 'eIF4G[KO]', 'GBA[KO]', 'Gdh[KO]',
#        'iPLA2-VIA[KO]', 'Loqs[KO]', 'Lrrk[KO]', 'nutcracker[KO]',
#        'Omi[KO]', 'Park[KO]', 'Pink1[KO]', 'Punch[KO]', 'Rab39[KO]',
#        'Rme8[KO]', 'Synj[KO]', 'Tango14[KO]', 'vham8,9[KO]', 'Vps13[KO]'],
#       dtype=object)

# %%
data["single_mutant_0"]=[good_names[gene] if gene in good_names else gene for gene in data["single_mutant_0"]]
data["single_mutant_1"]=[good_names[gene] if gene in good_names else gene for gene in data["single_mutant_1"]]

# %%
good_names
# Out:
# {'Auxillin[KO]': 'auxilin[KO-WS/+]',
#  'CG32000[KO]': 'anne[KO-WS/+]',
#  'CG5010[KO]': 'Chchd2[KO-WS/y]',
#  'CG5608[KO]': 'VAC14[KO-WS/+]',
#  'Coq2[KO]': 'Coq2[KO-WS/+]',
#  'Dj1a[KO];DJ1b[KO]': 'Dj1a[KO-WS/+];Dj1b[KO-WS/+]',
#  'eIF4G[KO]': 'eIF4G[KO-WS/+]',
#  'GBA[KO]': 'gba[KO-w+/+]',
#  'Gdh[KO]': 'Gdh[KO-WS/+]',
#  'iPLA2-VIA[KO]': 'iPLA2-VIA[KO-WS/+]',
#  'Loqs[KO]': 'loqs[KO-WS/+]',
#  'Lrrk[KO]': 'Lrrk[KO-WS/+]',
#  'nutcracker[KO]': 'nutcracker[KO-WS/+]',
#  'Omi[KO]': 'omi[KO-WS/+]',
#  'Park[KO]': 'park[1/+]',
#  'Pink1[KO]': 'Pink1[KO-WS/y]',
#  'Punch[KO]': 'Punch[KO-WS/+]',
#  'Rab39[KO]': 'Rab39[KO-WS/y]',
#  'Rme8[KO]': 'Rme-8[KO-WS/+]',
#  'Synj[KO]': 'Synj[KO-WS/+]',
#  'Tango14[KO]': 'Tango14[KO-WS/+]',
#  'vham8,9[KO]': 'VhaM8.9[KO-WS/+]',
#  'Vps13[KO]': 'Vps13[KO-WS/+]',
#  'Vps35[KO]': 'Vps35[KO-WS/+]'}

# %%
data["dist_0"]=[min_distance_to_interval((row["hdi0"], row["hdi1"]), 0)[0] for _, row in data.iterrows()]

# %%
data["side"]=[min_distance_to_interval((row["hdi0"], row["hdi1"]), critical_value=0)[1] for _, row in data.iterrows()]

# %%
data.to_csv(f"processed/{prefix}_output.csv")

# %%
plt.scatter(
    data.loc[data["side"]=="decrease", "mean(observed-expected)"],
    data.loc[data["side"]=="decrease", "dist_0"],
    color="b", label="Decrease"
)
plt.scatter(
    data.loc[data["side"]=="increase", "mean(observed-expected)"],
    data.loc[data["side"]=="increase", "dist_0"],
    color="r", label="Increase"
)

plt.scatter(
    data.loc[data["side"]=="neutral", "mean(observed-expected)"],
    data.loc[data["side"]=="neutral", "dist_0"],
    color="g", label="Neutral"
)
plt.legend()
plt.plot([0,2], [0,2], color="k")
plt.savefig(f"figures/{prefix}_correlation.png")

# %%
mutants=list(sorted(set(data["single_mutant_0"].unique().tolist() + data["single_mutant_1"].unique().tolist())))
import itertools
data_plot = np.zeros((len(mutants), len(mutants)))
data_plot[:]=np.nan
for mutant1, mutant2 in itertools.combinations(mutants, 2):
    i=mutants.index(mutant1)
    j=mutants.index(mutant2)
    dist=data.loc[
       ((data["single_mutant_0"]==mutant1)&(data["single_mutant_1"]==mutant2))|\
       ((data["single_mutant_1"]==mutant1)&(data["single_mutant_0"]==mutant2)),
        "dist_0"
    ]
    if dist.shape[0]==1:
        dist=dist.item()
        data_plot[i,j]=dist
        data_plot[j, i]=dist
    else:
        print(f"Pair not available: {mutant1}, {mutant2}")

data_plot=pd.DataFrame(data_plot)
data_plot.columns=mutants
data_plot.index=mutants

# %%
data_plot.to_csv(f"processed/{prefix}_genetic_interactions_dist_95hdi.csv")

# %%
# Create a heatmap using seaborn
plt.figure(figsize=(20, 20))
sns.heatmap(data_plot, annot=False, cmap='viridis', fmt=".1f", linewidths=.5)
plt.title('Interaction strength')
plt.xlabel('Genes')
plt.ylabel('Genes')
plt.savefig(f"figures/{prefix}_interaction_strength.png")
plt.savefig(f"figures/{prefix}_interaction_strength.svg")

# %%
[gene_pairs[pair_id] for pair_id in data.loc[data["hdi0"]>=1, "pair_id"]]
# Out:
# [['Coq2[KO]_+', 'Loqs[KO]_+', 'Loqs[KO]_+;Coq2[KO]_+'],
#  ['eIF4G[KO]_+', 'Loqs[KO]_+', 'Loqs[KO]_+;;eIF4G[KO]_+'],
#  ['GBA[KO]_+', 'vham8,9[KO]_+', 'GBA[KO]_vham8,9[KO]'],
#  ['Punch[KO]_+', 'Rme8[KO]_+', 'Punch[KO]_Rme8[KO]']]

# %%
genotypes=all_data["Genotype"].unique()
# genotypes

# %%
sms=["Pink1[KO]_y","Park[KO]_+"]
genes=[genotype for genotype in genotypes if genotype in sms or all(gene in genotype for gene in sms)]
data_hist=all_data.loc[all_data["Genotype"].isin(genes  + ["W1118"])]
fig=px.histogram(data_hist, x=metric, color="Genotype", nbins=100)
fig.show()

# %%
all_data["Genotype"].unique()
# Out:
# array(['Auxillin[KO]_+', 'Auxillin[KO]_iPLA2-VIA[KO]',
#        'Auxillin[KO]_Park[KO]', 'CG32000[KO]_+', 'CG5010[KO]_y',
#        'CG5010[KO]_y;;;CG32000[KO]_+', 'CG5010[KO]_y;;;eIF4G[KO]_+',
#        'CG5010[KO]_y;;Auxillin[KO]_+', 'CG5010[KO]_y;;CG5608[KO]_+',
#        'CG5010[KO]_y;;Coq2[KO]_+', 'CG5010[KO]_y;;GBA[KO]_+',
#        'CG5010[KO]_y;;Gdh[KO]_+', 'CG5010[KO]_y;;iPLA2-VIA[KO]_+',
#        'CG5010[KO]_y;;Lrrk[KO]_+', 'CG5010[KO]_y;;nutcracker[KO]_+',
#        'CG5010[KO]_y;;Omi[KO]_+', 'CG5010[KO]_y;;Park[KO]_+',
#        'CG5010[KO]_y;;vham8,9[KO]_+', 'CG5010[KO]_y;Loqs[KO]_+',
#        'CG5010[KO]_y;Punch[KO]_+', 'CG5010[KO]_y;Rme8[KO]_+',
#        'CG5010[KO]_y;Synj[KO]_+', 'CG5010[KO]_y;Tango14[KO]_+',
#        'CG5010[KO]_y;Vps35[KO]_+', 'CG5010[KO]_y;Dj1a[KO]_+;DJ1b[KO]_+',
#        'CG5608[KO]_+', 'CG5608[KO]_nutcracker[KO]', 'CG5608[KO]_Park[KO]',
#        'Coq2[KO]_+', 'Coq2[KO]_iPLA2-VIA[KO]', 'Coq2[KO]_nutcracker[KO]',
#        'Coq2[KO]_Park[KO]', 'Dj1a[KO]_+;Auxillin[KO]_DJ1b[KO]',
#        'Dj1a[KO]_+;CG5608[KO]_DJ1b[KO]', 'Dj1a[KO]_+;Coq2[KO]_DJ1b[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_+', 'Dj1a[KO]_+;DJ1b[KO]_+;CG32000[KO]_+',
#        'Dj1a[KO]_+;DJ1b[KO]_+;eIF4G[KO]_+', 'Dj1a[KO]_+;DJ1b[KO]_GBA[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_Gdh[KO]', 'Dj1a[KO]_+;DJ1b[KO]_iPLA2-VIA[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_Lrrk[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_nutcracker[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_Omi[KO]', 'Dj1a[KO]_+;DJ1b[KO]_Park[KO]',
#        'Dj1a[KO]_+;DJ1b[KO]_vham8,9[KO]', 'Dj1a[KO]_Loqs[KO];DJ1b[KO]_+',
#        'Dj1a[KO]_Punch[KO];DJ1b[KO]_+', 'Dj1a[KO]_Rme8[KO];DJ1b[KO]_+',
#        'Dj1a[KO]_Synj[KO];DJ1b[KO]_+', 'Dj1a[KO]_Tango14[KO];DJ1b[KO]_+',
#        'Dj1a[KO]_Vps13[KO];DJ1b[KO]_+', 'Dj1a[KO]_Vps35[KO];DJ1b[KO]_+',
#        'eIF4G[KO]_+', 'GBA[KO]_+', 'GBA[KO]_+;CG32000[KO]_+',
#        'GBA[KO]_+;eIF4G[KO]_+', 'GBA[KO]_iPLA2-VIA[KO]',
#        'GBA[KO]_Park[KO]', 'Gdh[KO]_+', 'Gdh[KO]_iPLA2-VIA[KO]',
#        'iPLA2-VIA[KO]_+', 'iPLA2-VIA[KO]_+;CG32000[KO]_+',
#        'iPLA2-VIA[KO]_+;eIF4G[KO]_+', 'iPLA2-VIA[KO]_CG5608[KO]',
#        'iPLA2-VIA[KO]_Lrrk[KO]', 'iPLA2-VIA[KO]_nutcracker[KO]',
#        'iPLA2-VIA[KO]_Omi[KO]', 'iPLA2-VIA[KO]_Park[KO]',
#        'iPLA2-VIA[KO]_vham8,9[KO]', 'Loqs[KO]_+',
#        'Loqs[KO]_+;iPLA2-VIA[KO]_+', 'Loqs[KO]_+;Park[KO]_+',
#        'Lrrk[KO]_+', 'Lrrk[KO]_nutcracker[KO]_+', 'Lrrk[KO]_Park[KO]',
#        'nutcracker[KO]_+', 'nutcracker[KO]_+;CG32000[KO]_+',
#        'nutcracker[KO]_Omi[KO]', 'nutcracker[KO]_Park[KO]',
#        'nutcracker[KO]_vham8,9[KO]', 'Omi[KO]_+', 'Omi[KO]_Park[KO]',
#        'Park[KO]_+', 'Park[KO]_+;CG32000[KO]_+', 'Park[KO]_+;eIF4G[KO]_+',
#        'Park[KO]_Gdh[KO]', 'Park[KO]_vham8,9[KO]', 'Pink1[KO]_y',
#        'Pink1[KO]_y;;;CG32000[KO]_+', 'Pink1[KO]_y;;;eIF4G[KO]_+',
#        'Pink1[KO]_y;;Auxillin[KO]_+', 'Pink1[KO]_y;;CG5608[KO]_+',
#        'Pink1[KO]_y;;Coq2[KO]_+', 'Pink1[KO]_y;;GBA[KO]_+',
#        'Pink1[KO]_y;;Gdh[KO]_+', 'Pink1[KO]_y;;iPLA2-VIA[KO]_+',
#        'Pink1[KO]_y;;Lrrk[KO]_+', 'Pink1[KO]_y;;nutcracker[KO]_+',
#        'Pink1[KO]_y;;Omi[KO]_+', 'Pink1[KO]_y;;vham8,9[KO]_+',
#        'Pink1[KO]_y;Dj1a[KO]_+;DJ1b[KO]_+', 'Pink1[KO]_y;Loqs[KO]_+',
#        'Pink1[KO]_y;Rme8[KO]_+', 'Pink1[KO]_y;Synj[KO]_+',
#        'Pink1[KO]_y;Tango14[KO]_+', 'Pink1[KO]_y;Vps13[KO]_+',
#        'Pink1[KO]_y;Vps35[KO]_+', 'Punch[KO]_+',
#        'Punch[KO]_+;iPLA2-VIA[KO]_+', 'Punch[KO]_+;Park[KO]_+',
#        'Rab39[KO]_y', 'Rab39[KO]_y;;;CG32000_+',
#        'Rab39[KO]_y;;;eIF4G[KO]_+', 'Rab39[KO]_y;;Auxillin[KO]_+',
#        'Rab39[KO]_y;;CG5608[KO]_+', 'Rab39[KO]_y;;Coq2[KO]_+',
#        'Rab39[KO]_y;;GBA[KO]_+', 'Rab39[KO]_y;;Gdh[KO]_+',
#        'Rab39[KO]_y;;iPLA-2VIA[KO]_+', 'Rab39[KO]_y;;Lrrk[KO]_+',
#        'Rab39[KO]_y;;nutcracker[KO]_+', 'Rab39[KO]_y;;Omi[KO]_+',
#        'Rab39[KO]_y;;Park[KO]_+', 'Rab39[KO]_y;;Rme8[KO]_+',
#        'Rab39[KO]_y;;vham8,9[KO]_+', 'Rab39[KO]_y;Dj1a[KO]_+;DJ1b[KO]_+',
#        'Rab39[KO]_y;Loqs[KO]_+', 'Rab39[KO]_y;Punch[KO]_+',
#        'Rab39[KO]_y;Synj[KO]_+', 'Rab39[KO]_y;Tango14[KO]_+',
#        'Rab39[KO]_y;Vps13[KO]_+', 'Rab39[KO]_y;Vps35[KO]_+', 'Rme8[KO]_+',
#        'Rme8[KO]_+;iPLA2-VIA[KO]_+', 'Rme8[KO]_+;nutcracker[KO]_+',
#        'Rme8[KO]_+;Park[KO]_+', 'Synj[KO]_+', 'Synj[KO]_+;Auxillin[KO]_+',
#        'Synj[KO]_+;GBA[KO]_+', 'Synj[KO]_+;iPLA2-VIA[KO]_+',
#        'Synj[KO]_+;nutcracker[KO]_+', 'Synj[KO]_+;Park[KO]_+',
#        'Tango14[KO]_+', 'Tango14[KO]_+;;CG32000[KO]_+',
#        'Tango14[KO]_+;iPLA2-VIA[KO]_+', 'Tango14[KO]_+;nutcracker[KO]_+',
#        'Tango14[KO]_+;Park[KO]_+', 'vham8,9[KO]_+', 'Vps13[KO]_+',
#        'Vps13[KO]_+;iPLA2-VIA[KO]_+', 'Vps13[KO]_+;Park[KO]_+',
#        'Vps35[KO]_+', 'Vps35[KO]_+;iPLA2-VIA[KO]_+',
#        'Vps35[KO]_+;Park[KO]_+', 'W1118', 'CG5010[KO]_y;Vps13[KO]_+',
#        'Tango14[KO]_+;GBA[KO]_+', 'Vps13[KO]_+;GBA[KO]_+',
#        'Vps35[KO]_+;GBA[KO]_+', 'Auxillin[KO]_nutcracker[KO]',
#        'nutcracker[KO]_+;eIF4G[KO]_+', 'Vps35[KO]_+;nutcracker[KO]_+',
#        'Auxillin[KO]_+;CG32000[KO]_+', 'Auxillin[KO]_vham8,9[KO]',
#        'Coq2[KO]_+;CG32000[KO]_+', 'Coq2[KO]_GBA[KO]',
#        'CG32000[KO]_eIF4G[KO]', 'GBA[KO]_Lrrk[KO]',
#        'GBA[KO]_nutcracker[KO]', 'Loqs[KO]_+;GBA[KO]_+',
#        'Loqs[KO]_+;Lrrk[KO]_+', 'Lrrk[KO]_+;CG32000[KO]_+',
#        'Lrrk[KO]_vham8,9[KO]', 'Rme8[KO]_+;;CG32000[KO]_+',
#        'Rme8[KO]_+;Auxillin[KO]_+', 'Rme8[KO]_+;GBA[KO]_+',
#        'Rme8[KO]_+;vham8,9[KO]_+', 'Synj[KO]_+;;CG32000[KO]_+',
#        'Tango14[KO]_Vps13[KO]', 'vham8,9[KO]_+;CG32000[KO]_+',
#        'Vps13[KO]_+;;CG32000[KO]_+', 'Vps35[KO]_+;Lrrk[KO]_+',
#        'Vps35[KO]_+;vham8,9[KO]_+', 'Auxillin[KO]_+;eIF4G[KO]_+',
#        'Auxillin[KO]_Lrrk[KO]', 'CG5608[KO]_GBA[KO]',
#        'CG5608[KO]_Lrrk[KO]', 'Loqs[KO]_+;;CG32000[KO]_+',
#        'Loqs[KO]_+;nutcracker[KO]_+', 'Lrrk[KO]_+;eIF4G[KO]_+',
#        'Punch[KO]_+;Lrrk[KO]_+', 'Punch[KO]_+;nutcracker[KO]_+',
#        'Rme8[KO]_+;;eIF4G[KO]_+', 'Rme8[KO]_+;Lrrk[KO]_+',
#        'Rme8[KO]_Vps35[KO]', 'Synj[KO]_+;Lrrk[KO]_+',
#        'Tango14[KO]_+;Lrrk[KO]_+', 'vham8,9[KO]_+;eIF4G[KO]_+',
#        'Vps13[KO]_+;eIF4G[KO]_+', 'Vps13[KO]_+;Lrrk[KO]_+',
#        'Vps13[KO]_+;nutcracker[KO]_+', 'Vps13[KO]_+;vham8,9[KO]_+',
#        'Coq2[KO]_Lrrk[KO]', 'Coq2[KO]_vham8,9[KO]',
#        'Loqs[KO]_+;vham8,9[KO]_+', 'Lrrk[KO]_Omi[KO]',
#        'Omi[KO]_+;CG32000[KO]_+', 'Rme8[KO]_+;Coq2[KO]_+',
#        'Rme8[KO]_Tango14[KO]', 'Synj[KO]_Tango14[KO]',
#        'Tango14[KO]_+;;eIF4G[KO]_+', 'Tango14[KO]_+;Auxillin[KO]_+',
#        'Tango14[KO]_+;Coq2[KO]_+', 'Tango14[KO]_+;Omi[KO]_+',
#        'Vps35[KO]_+;;CG32000[KO]_+', 'Auxillin[KO]_Coq2[KO]',
#        'CG5608[KO]_Coq2[KO]', 'Coq2[KO]_+;eIF4G[KO]_+',
#        'Coq2[KO]_Omi[KO]', 'Gdh[KO]_+;CG32000[KO]_+',
#        'Gdh[KO]_vham8,9[KO]', 'Loqs[KO]_+;Coq2[KO]_+',
#        'Loqs[KO]_Tango14[KO]', 'Omi[KO]_+;eIF4G[KO]_+',
#        'Punch[KO]_+;;CG32000[KO]_+', 'Punch[KO]_+;vham8,9[KO]_+',
#        'Rme8[KO]_+;CG5608[KO]_+', 'Rme8[KO]_+;Omi[KO]_+',
#        'Rme8[KO]_Synj[KO]', 'Synj[KO]_+;;eIF4G[KO]_+',
#        'Synj[KO]_+;Coq2[KO]_+', 'Synj[KO]_+;vham8,9[KO]_+',
#        'Synj[KO]_+;Omi[KO]_+', 'Synj[KO]_Vps13[KO]', 'Synj[KO]_Vps35[KO]',
#        'Tango14[KO]_+;CG5608[KO]_+', 'Tango14[KO]_+;vham8,9[KO]_+',
#        'Auxillin[KO]_CG5608[KO]', 'Auxillin[KO]_Omi[KO]',
#        'CG5608[KO]_+;CG32000[KO]_+', 'CG5608[KO]_+;eIF4G[KO]_+',
#        'CG5608[KO]_Omi[KO]', 'CG5608[KO]_vham8,9[KO]', 'Coq2[KO]_Gdh[KO]',
#        'GBA[KO]_vham8,9[KO]', 'Gdh[KO]_+;eIF4G[KO]_+', 'Gdh[KO]_Lrrk[KO]',
#        'Loqs[KO]_+;;eIF4G[KO]_+', 'Loqs[KO]_+;Omi[KO]_+',
#        'Loqs[KO]_Rme8[KO]', 'Loqs[KO]_Synj[KO]', 'Loqs[KO]_Vps35[KO]',
#        'Omi[KO]_vham8,9[KO]', 'Punch[KO]_+;;eIF4G[KO]_+',
#        'Punch[KO]_+;Coq2[KO]_+', 'Punch[KO]_Rme8[KO]',
#        'Punch[KO]_Synj[KO]', 'Rme8[KO]_+;Gdh[KO]_+', 'Rme8[KO]_Vps13[KO]',
#        'Synj[KO]_+;CG5608[KO]_+', 'Synj[KO]_+;Gdh[KO]_+',
#        'Vps13[KO]_+;Auxillin[KO]_+', 'Vps13[KO]_+;Coq2[KO]_+',
#        'Vps13[KO]_+;Omi[KO]_+', 'Vps35[KO]_+;;eIF4G[KO]_+',
#        'Vps35[KO]_+;Coq2[KO]_+', 'Auxillin[KO]_GBA[KO]',
#        'GBA[KO]_Gdh[KO]', 'Gdh[KO]_Omi[KO]', 'Loqs[KO]_+;Auxillin[KO]_+',
#        'Loqs[KO]_+;Gdh[KO]_+', 'Loqs[KO]_Punch[KO]',
#        'Punch[KO]_+;Auxillin[KO]_+', 'Punch[KO]_+;CG5608[KO]_+',
#        'Punch[KO]_+;Gdh[KO]_+', 'Punch[KO]_+;Omi[KO]_+',
#        'Punch[KO]_Tango14[KO]', 'Punch[KO]_Vps13[KO]',
#        'Tango14[KO]_+;Gdh[KO]_+', 'Vps13[KO]_+;Gdh[KO]_+',
#        'Vps13[KO]_+;CG5608[KO]_+', 'Vps13[KO]_Vps35[KO]',
#        'Vps35[KO]_+;Auxillin[KO]_+', 'Vps35[KO]_+;CG5608[KO]_+',
#        'Vps35[KO]_+;Gdh[KO]_+', 'Vps35[KO]_+;Omi[KO]_+',
#        'Loqs[KO]_+;CG5608[KO]_+', 'Loqs[KO]_Vps13[KO]',
#        'Punch[KO]_Vps35[KO]', 'Tango14[KO]_Vps35[KO]',
#        'Auxillin[KO]_Gdh[KO]', 'Punch[KO]_+;GBA[KO]_+',
#        'CG5608[KO]_Gdh[KO]', 'Gdh[KO]_nutcracker[KO]', 'GBA[KO]_Omi[KO]',
#        'Pink1[KO]_y;Punch[KO]_+;', 'Pink1[KO]_Rab39[KO]_y;;',
#        'CG5010[KO]_Rab39[KO]_y;;', 'CG5010[KO]_Pink1[KO]_y;;',
#        'Pink1[KO]_y;;Park[KO]_+'], dtype=object)
